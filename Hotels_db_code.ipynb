# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl
import json
import re
import sys
from splinter import Browser
import os
import csv
import threading
import requests
import pymongo
import pandas as pd
import string

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
db = client.Hotels_db
collection = db.items

# %%
#executable_path = {'executable_path': 'chromedriver.exe'}
#browser = Browser('chrome', **executable_path, headless=False)

# %%
#url="https://ca.hotels.com/search.do?resolved-location=GEO_LOCATION%3AToronto,%20ON%20M2N%200H1,%20Canada%7C43.75801086425781%7C-79.40361022949219%3AGEOCODE%3AUNKNOWN&q-destination=Toronto,%20ON%20M2N%200H1,%20Canada&q-check-in=2019-04-16&q-check-out=2019-04-17&q-rooms=1&q-room-0-adults=2&q-room-0-children=0&sort-order=DISTANCE_FROM_LANDMARK"
##url="https://ca.hotels.com/search.do?resolved-location=GEO_LOCATION%3AToronto,%20ON%20M2N%200H1,%20Canada%7C43.75801086425781%7C-79.40361022949219%3AGEOCODE%3AUNKNOWN&q-destination=Toronto,%20ON%20M2N%200H1,%20Canada&q-check-in=2019-04-16&q-check-out=2019-04-17&q-rooms=1&q-room-0-adults=2&q-room-0-children=0&sort-order=DISTANCE_FROM_LANDMARK"
#browser.visit(url)
#html = browser.html
#soup = BeautifulSoup(html, 'html.parser')

# %%
url_list= ["https://ca.hotels.com/search.do?resolved-location=GEO_LOCATION%3AToronto,%20ON%20M5T%202V4,%20Canada%7C43.650338%7C-79.402688%3AGEOCODE%3AUNKNOWN&q-destination=Toronto,%20ON%20M5T%202V4,%20Canada&q-check-in=2019-04-19&q-check-out=2019-04-20&q-rooms=1&q-room-0-adults=2&q-room-0-children=0&sort-order=DISTANCE_FROM_LANDMARK","https://ca.hotels.com/search.do?resolved-location=GEO_LOCATION%3AScarborough,%20ON%20M1H%202Z1,%20Canada%7C43.7827949%7C-79.2384188%3AGEOCODE%3AUNKNOWN&q-destination=Scarborough,%20ON%20M1H%202Z1,%20Canada&q-check-in=2019-04-19&q-check-out=2019-04-20&q-rooms=1&q-room-0-adults=2&q-room-0-children=0&sort-order=DISTANCE_FROM_LANDMARK","https://ca.hotels.com/search.do?resolved-location=GEO_LOCATION%3AEtobicoke,%20ON%20M9C%205K5,%20Canada%7C43.6511117%7C-79.6017779%3AGEOCODE%3AUNKNOWN&q-destination=Etobicoke,%20ON%20M9C%205K5,%20Canada&q-check-in=2019-04-19&q-check-out=2019-04-20&q-rooms=1&q-room-0-adults=2&q-room-0-children=0&sort-order=DISTANCE_FROM_LANDMARK","https://ca.hotels.com/search.do?resolved-location=GEO_LOCATION%3AEtobicoke,%20ON%20M9W%205E7,%20Canada%7C43.6788872%7C-79.5908946%3AGEOCODE%3AUNKNOWN&q-destination=Etobicoke,%20ON%20M9W%205E7,%20Canada&q-check-in=2019-04-19&q-check-out=2019-04-20&q-rooms=1&q-room-0-adults=2&q-room-0-children=0&sort-order=DISTANCE_FROM_LANDMARK","https://ca.hotels.com/search.do?resolved-location=GEO_LOCATION%3AToronto,%20ON%20M4P%202L2,%20Canada%7C43.7090152%7C-79.3906374%3AGEOCODE%3AUNKNOWN&q-destination=Toronto,%20ON%20M4P%202L2,%20Canada&q-check-in=2019-04-19&q-check-out=2019-04-20&q-rooms=1&q-room-0-adults=2&q-room-0-children=0&sort-order=DISTANCE_FROM_LANDMARK","https://ca.hotels.com/search.do?resolved-location=GEO_LOCATION%3AToronto,%20ON%20M5V%201J6,%20Canada%7C43.6458413%7C-79.3918689%3AGEOCODE%3AUNKNOWN&q-destination=Toronto,%20ON%20M5V%201J6,%20Canada&q-check-in=2019-04-19&q-check-out=2019-04-20&q-rooms=1&q-room-0-adults=2&q-room-0-children=0&sort-order=DISTANCE_FROM_LANDMARK","https://ca.hotels.com/search.do?resolved-location=GEO_LOCATION%3AToronto,%20ON%20M5B%202G8,%20Canada%7C43.655992%7C-79.3783212%3AGEOCODE%3AUNKNOWN&q-destination=Toronto,%20ON%20M5B%202G8,%20Canada&q-check-in=2019-04-19&q-check-out=2019-04-20&q-rooms=1&q-room-0-adults=2&q-room-0-children=0&sort-order=DISTANCE_FROM_LANDMARK","https://ca.hotels.com/search.do?resolved-location=GEO_LOCATION%3AToronto,%20ON%20M5C%201N2,%20Canada%7C43.6516588%7C-79.3779693%3AGEOCODE%3AUNKNOWN&q-destination=Toronto,%20ON%20M5C%201N2,%20Canada&q-check-in=2019-04-19&q-check-out=2019-04-20&q-rooms=1&q-room-0-adults=2&q-room-0-children=0&sort-order=DISTANCE_FROM_LANDMARK","https://ca.hotels.com/search.do?resolved-location=GEO_LOCATION%3AToronto,%20ON%20M5G%201Z4,%20Canada%7C43.6586116%7C-79.3833359%3AGEOCODE%3AUNKNOWN&q-destination=Toronto,%20ON%20M5G%201Z4,%20Canada&q-check-in=2019-04-19&q-check-out=2019-04-20&q-rooms=1&q-room-0-adults=2&q-room-0-children=0&sort-order=DISTANCE_FROM_LANDMARK","https://ca.hotels.com/search.do?resolved-location=GEO_LOCATION%3AEtobicoke,%20ON%20M9W%206K5,%20Canada%7C43.7208308%7C-79.5989694%3AGEOCODE%3AUNKNOWN&q-destination=Etobicoke,%20ON%20M9W%206K5,%20Canada&q-check-in=2019-04-19&q-check-out=2019-04-20&q-rooms=1&q-room-0-adults=2&q-room-0-children=0&sort-order=DISTANCE_FROM_LANDMARK"]
post = {}

source_loaded = 'Hotels.com'
for link in url_list:
       
    executable_path = {'executable_path': 'chromedriver.exe'}
    browser = Browser('chrome', **executable_path, headless=False)
    browser.visit(link)
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    results = soup.find_all('section', class_="hotel-wrap")
        
    for result in results:
    # Error handling
        try:
            # Identify and return title of listing
            address = result.find('address', class_="contact").text

            # # Identify and return price of listing
            price = result.find('a', class_="price-link").text


            # Print results only if postal code and price are available
            if (address,price):
                print('-------------')
                address_split = address.split(sep=',')
                if len(address_split) > 6:
                    postal_code = address_split[4]
                    print(f'Postal code: {postal_code}')
                
                else :
                    postal_code = address_split[3]
                    print(f'Postal code: {postal_code}')

                prices = price.split(sep='CAD')
                
                if len(prices) > 2:
                    new_prices = prices[1]
                    print(f'new price is: {new_prices}')

                else :
                    new_prices = prices[0]
                    print(f'new price is: {new_prices}')
                # Dictionary to be inserted as a MongoDB document
                post = {
                    'postal_code': postal_code,
                    'price': new_prices,
                    'source_loaded': source_loaded
                    }
                collection.insert_one(post)
                # Convert to DataFrame
                #hotel_pd = pd.DataFrame(post)
                #hotel_pd = hotel_pd[["postal_code", "price","source_loaded"]]
                
                #hotel_pd.to_csv("hotel_pd_data.csv", encoding="utf-8", index=False)


        except AttributeError as e:
            print(e)
# Out:
# -------------
# Postal code:  M5T2V4
# new price is: $119
# -------------
# Postal code:  M5T2S3
# new price is: $139
# -------------
# Postal code:  M5T 1H5
# new price is: $59
# -------------
# Postal code:  M6J 2G4
# new price is: $134
# -------------
# Postal code:  M5T1E8
# new price is: $69
# -------------
# Postal code:  M1H2Z1
# new price is: $154
# -------------
# Postal code:  M1H2Z1
# new price is: $140
# -------------
# Postal code:  M1B3C6
# new price is: $118
# -------------
# Postal code:  M1T-3G2
# new price is: $154
# -------------
# Postal code:  Canada
# new price is: $58
# -------------
# Postal code:  M9C5K5
# new price is: $179
# -------------
# Postal code:  M9C 5K5
# new price is: $149
# -------------
# Postal code:  M9C 5K5
# new price is: $109
# -------------
# Postal code:  L4W4X2
# new price is: $139
# -------------
# Postal code:  L4W5R2
# new price is: $139
# -------------
# Postal code:  M9W 5E7
# new price is: $146
# -------------
# ...

# %%
#db.items.remove()
listings = db.items.find()
listings

# %%
import json

# %%
# Display items in MongoDB collection
df =  pd.DataFrame(list(listings))
df.head()
# Out:
#                         _id postal_code  price source_loaded
# 0  5cb7451b7fbad250204986b0      M5T2V4  $119     Hotels.com
# 1  5cb7451b7fbad250204986b1      M5T2S3  $139     Hotels.com
# 2  5cb7451b7fbad250204986b2     M5T 1H5   $59     Hotels.com
# 3  5cb7451b7fbad250204986b3     M6J 2G4  $139     Hotels.com
# 4  5cb7451b7fbad250204986b4      M5T1E8   $69     Hotels.com

# %%
new_customer_location_df = df[["postal_code", "price", "source_loaded"]].copy()
new_customer_location_df.head()
# Out:
#   postal_code  price source_loaded
# 0      M5T2V4  $119     Hotels.com
# 1      M5T2S3  $139     Hotels.com
# 2     M5T 1H5   $59     Hotels.com
# 3     M6J 2G4  $139     Hotels.com
# 4      M5T1E8   $69     Hotels.com

# %%
new_customer_location_df.drop_duplicates("postal_code", inplace=True)
new_customer_location_df.set_index("postal_code", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-c5fdf6455b15> in <module>
# ----> 1 new_customer_location_df.drop_duplicates("postal_code", inplace=True)
#       2 new_customer_location_df.set_index("postal_code", inplace=True)
#       3 new_customer_location_df.head()
#
# ~\anaconda\Anaconda3\lib\site-packages\pandas\core\frame.py in drop_duplicates(self, subset, keep, inplace)
#    4329         """
#    4330         inplace = validate_bool_kwarg(inplace, 'inplace')
# -> 4331         duplicated = self.duplicated(subset, keep=keep)
#    4332
#    4333         if inplace:
#
# ~\anaconda\Anaconda3\lib\site-packages\pandas\core\frame.py in duplicated(self, subset, keep)
#    4379         diff = Index(subset).difference(self.columns)
#    4380         if not diff.empty:
# -> 4381             raise KeyError(diff)
#    4382
# ...

# %%
new_customer_location_df.head()
# Out:
#              price source_loaded
# postal_code
#  M5T2V4      $119     Hotels.com
#  M5T2S3      $139     Hotels.com
#  M5T 1H5      $59     Hotels.com
#  M6J 2G4     $139     Hotels.com
#  M5T1E8       $69     Hotels.com

# %%
new_customer_location_df.to_excel("Hotel_list.xlsx", index=True)
